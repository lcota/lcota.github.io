# %%
import pandas as pd

# %%
cpi = pd.read_parquet("workspace/cpi_fred_factors.pq")

# %%
cpi
# Out:
#                    date  usa.cpi  year    cpiyoy cpi.hml  3M_rising  \
# refmonthyear
# JAN.1914     1914-01-01   10.000  1914  2.040816     MED      False
# FEB.1914     1914-02-01    9.900  1914  1.020408     MED      False
# MAR.1914     1914-03-01    9.900  1914  1.020408     MED      False
# APR.1914     1914-04-01    9.800  1914  0.000000     LOW      False
# MAY.1914     1914-05-01    9.900  1914  2.061856     MED      False
# ...                 ...      ...   ...       ...     ...        ...
# JUL.2023     2023-07-01  305.691  2023  3.177780    HIGH       True
# AUG.2023     2023-08-01  307.026  2023  3.665112    HIGH       True
# SEP.2023     2023-09-01  307.789  2023  3.699698    HIGH       True
# OCT.2023     2023-10-01  307.671  2023  3.241145    HIGH       True
# NOV.2023     2023-11-01  307.051  2023  3.137271    HIGH       True
#
#               6M_rising  9M_rising  12M_rising  3Mchg  6Mchg   9Mchg  12Mchg
# refmonthyear
# ...
